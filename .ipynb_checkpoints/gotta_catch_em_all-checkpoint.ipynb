# %%
import pandas as pd

# %%
raw_data = pd.read_csv('pokemon_trainer_application_data.csv')
# Out:
# /Users/saurav/Distributions/venv/lib/python3.6/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (69,70,71,72) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = 100

# %%
raw_data[:10]
# Out:
#   ApplicationStatus ApplicationType   ApplyDate CurrentlyEmployed  \
# 0   Filed Not Hired       Applicant  2013-11-26             False
# 1   Filed Not Hired       Applicant  2013-11-27              True
# 2   Filed Not Hired       Applicant  2013-11-22               NaN
# 3   Filed Not Hired       Applicant  2013-11-23              True
# 4               New       Applicant  2013-11-23              True
# 5   Filed Not Hired       Applicant  2013-11-23             False
# 6               New       Applicant  2013-11-24              True
# 7               New       Applicant  2013-11-24              True
# 8   Filed Not Hired       Applicant  2013-11-24               NaN
# 9   Filed Not Hired       Applicant  2013-11-25              True
#
#   CurrentlyTrainingPokemon CurrentlyWorkInThisRegion  GraduateSchoolGPA  \
# 0                      NaN                     False                NaN
# 1                      NaN                     False                NaN
# ...

# %%
raw_data.describe()
# Out:
#        GraduateSchoolGPA  HighSchoolGPA  OtherSchoolGPA  TechnicalSchoolGPA  \
# count        3889.000000   27206.000000     3781.000000        10241.000000
# mean            3.478934       3.203623        3.463853            3.477138
# std             0.476177       0.516601        0.482387            0.478480
# min             0.000000       0.000000        0.000000            0.000000
# 25%             3.200000       3.000000        3.070000            3.000000
# 50%             3.550000       3.200000        3.500000            3.500000
# 75%             3.800000       3.570000        3.890000            3.900000
# max             4.300000       4.300000        4.200000            4.300000
#
#        TotalYearsOfExp  UndergradSchoolGPA         hired
# count     96914.000000        24361.000000  96321.000000
# mean          4.154095            3.213768      0.017213
# std           3.469671            0.451540      0.130066
# ...

# %%
len(raw_data)
# Out:
# 100000

# %%
raw_data.count()
# Out:
# ApplicationStatus                                 99996
# ApplicationType                                  100000
# ApplyDate                                        100000
# CurrentlyEmployed                                 82596
# CurrentlyTrainingPokemon                           3911
# CurrentlyWorkInThisRegion                         92482
# GraduateSchoolGPA                                  3889
# GraduateSchoolGraduate                             9789
# GymBadge1Pokemon                                  34973
# GymBadge2Pokemon                                  16411
# GymBadge3Pokemon                                   5901
# GymBadge4Pokemon                                   1812
# GymBadgePerm1                                     93473
# GymBadgePerm2                                     93473
# GymBadgePerm3                                     93473
# GymBadgePerm4                                     93473
# GymBadgeTemp1                                     93473
# ...

# %% [markdown]
# We see that `hired`, our target column, has the value missing for about ~4,000 rows. Without any background for assumptions, it may be safe to drop these rows so as to not contaminate the model.

# %%
raw_data.dropna(subset=['hired'], inplace=True)
raw_data.count()
# Out:
# ApplicationStatus                                96321
# ApplicationType                                  96321
# ApplyDate                                        96321
# CurrentlyEmployed                                79635
# CurrentlyTrainingPokemon                          3761
# CurrentlyWorkInThisRegion                        89135
# GraduateSchoolGPA                                 3739
# GraduateSchoolGraduate                            9425
# GymBadge1Pokemon                                 33786
# GymBadge2Pokemon                                 15856
# GymBadge3Pokemon                                  5688
# GymBadge4Pokemon                                  1748
# GymBadgePerm1                                    90062
# GymBadgePerm2                                    90062
# GymBadgePerm3                                    90062
# GymBadgePerm4                                    90062
# GymBadgeTemp1                                    90062
# ...
